# %% [markdown]
# # 30 — Matched dataset and verification
#
# Build 118 natural reciprocal prompt pairs, freeze calibration-only layer/WRITTEN selection, enforce clean-answer and WRITTEN gates, and log every failure as UNVERIFIED.

# %%
import os
import sys
from pathlib import Path

ROOT = Path('/home/jovyan/j-space-thoughts')
os.chdir(ROOT)
sys.path.insert(0, str(ROOT))
driver = ROOT / 'scripts/run_symmetric_phase30.py'
exec(compile(driver.read_text(), str(driver), 'exec'), globals(), globals())
# Out:
# {
#   "hf_path": "/home/jovyan/.local/bin/hf",
#   "hf_identity": "user=sushmanth orgs=devoworm-group,sushmanthreddy,OWG,syscv-community,context-course",
#   "gpu_csv": "memory.total [MiB], memory.free [MiB]\n143771 MiB, 143069 MiB",
#   "hf_disk": "Filesystem                                                                             Size  Used Avail Use% Mounted on\nalln01-ac01-kai-it-prd.cisco.com:/kai_it_prd_pvc_1fbd1df6_fc34_4b57_8a48_89f42afbf0d9  100G   63G   38G  63% /home/jovyan"
# }
# Loading weights:   0%|          | 0/339 [00:00<?, ?it/s]
# /home/jovyan/j-space-thoughts/.venv/lib/python3.11/site-packages/transformers/models/qwen2/modeling_qwen2.py:108: UserWarning: Deterministic behavior was enabled with either `torch.use_deterministic_algorithms(True)` or `at::Context::setDeterministicAlgorithms(true)`, but this operation is not deterministic because it uses CuBLAS and you have CUDA >= 10.2. To enable deterministic behavior in this case, you must set an environment variable before running your PyTorch application: CUBLAS_WORKSPACE_CONFIG=:4096:8 or CUBLAS_WORKSPACE_CONFIG=:16:8. For more information, go to https://docs.nvidia.com/cuda/cublas/index.html#results-reproducibility (Triggered internally at ../aten/src/ATen/Context.cpp:208.)
#   freqs = (inv_freq_expanded.float() @ position_ids_expanded.float()).transpose(1, 2)
# /opt/conda/lib/python3.11/site-packages/torch/nn/modules/linear.py:125: UserWarning: Deterministic behavior was enabled with either `torch.use_deterministic_algorithms(True)` or `at::Context::setDeterministicAlgorithms(true)`, but this operation is not deterministic because it uses CuBLAS and you have CUDA >= 10.2. To enable deterministic behavior in this case, you must set an environment variable before running your PyTorch application: CUBLAS_WORKSPACE_CONFIG=:4096:8 or CUBLAS_WORKSPACE_CONFIG=:16:8. For more information, go to https://docs.nvidia.com/cuda/cublas/index.html#results-reproducibility (Triggered internally at ../aten/src/ATen/Context.cpp:208.)
#   return F.linear(input, self.weight, self.bias)
# G1 PASS: 20 prompts, max mean KL=1.660e-08
# candidate pool {'n_candidates': 118, 'n_dependency_groups': 33, 'n_calibration_pairs': 25, 'n_evaluation_pairs': 93}
# /home/jovyan/j-space-thoughts/src/jlens_iface.py:192: UserWarning: Deterministic behavior was enabled with either `torch.use_deterministic_algorithms(True)` or `at::Context::setDeterministicAlgorithms(true)`, but this operation is not deterministic because it uses CuBLAS and you have CUDA >= 10.2. To enable deterministic behavior in this case, you must set an environment variable before running your PyTorch application: CUBLAS_WORKSPACE_CONFIG=:4096:8 or CUBLAS_WORKSPACE_CONFIG=:16:8. For more information, go to https://docs.nvidia.com/cuda/cublas/index.html#results-reproducibility (Triggered internally at ../aten/src/ATen/Context.cpp:208.)
#   directions = F.normalize(rows @ jacobian, dim=-1)
# calibration L13: n=21 median|C| engine=0.0068 dashboard=0.0131 separation=-0.0062
# calibration L14: n=18 median|C| engine=0.0103 dashboard=0.0168 separation=-0.0065
# calibration L15: n=16 median|C| engine=0.0036 dashboard=0.0124 separation=-0.0088
# calibration L16: n=17 median|C| engine=0.0052 dashboard=0.0188 separation=-0.0136
# calibration L17: n=14 median|C| engine=0.0055 dashboard=0.0132 separation=-0.0077
# calibration L18: n=24 median|C| engine=0.0044 dashboard=0.0059 separation=-0.0015
# calibration L19: n=16 median|C| engine=0.0060 dashboard=0.0044 separation=0.0017
# calibration L20: n=24 median|C| engine=0.0042 dashboard=0.0049 separation=-0.0008
# calibration L21: n=18 median|C| engine=0.0066 dashboard=0.0038 separation=0.0028
# calibration L22: n=17 median|C| engine=0.0076 dashboard=0.0039 separation=0.0037
# calibration L23: n=21 median|C| engine=0.0063 dashboard=0.0053 separation=0.0009
# calibration L24: n=18 median|C| engine=0.0054 dashboard=0.0036 separation=0.0018
# calibration L25: n=22 median|C| engine=0.0040 dashboard=0.0036 separation=0.0004
# calibration L26: n=22 median|C| engine=0.0007 dashboard=0.0033 separation=-0.0026
# frozen selection {'layer': 22, 'position_rule': 'last_token_of_shared_context_prefix', 'calibration_causal_separation': 0.003699788583509514, 'threshold': 3.2664365768432617, 'own_recall': 0.8, 'foil_specificity': 0.72, 'balanced_accuracy': 0.76}
# verification counts {'candidates': 118, 'calibration_pairs': 25, 'evaluation_pairs': 93, 'verified_pairs': 61, 'unverified_pairs': 32, 'engine_verified_evaluation_pairs': 61}
# {
#   "raw_sha256": "f1b5285b4afecc4baec511ca93b5788d0b9ca8ec8638d3a3d1250606e617612d",
#   "direction_sha256": "81c398e3084f74096d21ee5eb0b2e2b72e673f063d9affb879a60406ba71c595",
#   "clean_manifest_sha256": "6792606f72d391f0c4104b797d47bc6bf5bfb27bc05d93cbcbfd5e9a375e9c02"
# }
