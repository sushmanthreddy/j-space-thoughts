# %% [markdown]
# # 33 — Held-out trust check
#
# Join the independently generated causal truth and cheap scores, evaluate grouped held-out AUC/CIs, create F1--F4, and make the pre-registered one-line GO/NO-GO decision.

# %%
import os
import sys
from pathlib import Path

ROOT = Path('/home/jovyan/j-space-thoughts')
os.chdir(ROOT)
sys.path.insert(0, str(ROOT))
driver = ROOT / 'scripts/run_symmetric_phase33.py'
exec(compile(driver.read_text(), str(driver), 'exec'), globals(), globals())
