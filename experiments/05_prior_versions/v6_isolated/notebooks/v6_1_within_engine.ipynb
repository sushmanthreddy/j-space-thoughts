# %% [markdown]
# # v6.1 — Within-engine graded-use check
#
# Read the frozen engine C and READ values without recomputation, then calculate dependency-group bootstrap Spearman correlations. This is the decisive stress test.

# %%
import os
import sys
from pathlib import Path

root = Path('/home/jovyan/j-space-thoughts')
os.chdir(root)
sys.path.insert(0, str(root))
script = Path('/home/jovyan/j-space-thoughts/scripts/run_within_engine_v6.py')
exec(compile(script.read_text(), str(script), 'exec'), {'__name__': '__main__'})
# Out:
# CHECK 1 complete
# READ_IG: rho=-0.179110, CI95=[-0.431377, 0.126014]
# READ_local: rho=-0.159288, CI95=[-0.450370, 0.194731]
# weight_norm_baseline: rho=-0.252468, CI95=[-0.491833, 0.051357]
# within-engine AUC NOT_RUN_NO_PREREGISTERED_OR_NATURAL_SPLIT
# interpretation ARTIFACT_SIDE_CI_SPANS_ZERO
# metrics /home/jovyan/j-space-thoughts/results/v6/metrics_v6.json
# figure /home/jovyan/j-space-thoughts/results/v6/figures/F_v6_1_engine_only_read_vs_c.png
