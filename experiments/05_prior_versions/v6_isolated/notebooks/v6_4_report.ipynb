# %% [markdown]
# # v6.4 — Isolated stress-test report and decision
#
# Combine the three frozen checks, apply the preregistered conjunction rule, audit the firewall and namespace isolation, and write `results/v6/RESULTS_v6.md`.

# %%
import os
import sys
from pathlib import Path

root = Path('/home/jovyan/j-space-thoughts')
os.chdir(root)
sys.path.insert(0, str(root))
script = root / 'scripts/run_stress_report_v6.py'
exec(compile(script.read_text(), str(script), 'exec'), {'__name__': '__main__'})
# Out:
# ARTIFACT (partial): READ_IG survives the answer-type-matched control, but has no positive graded association within engines (rho=-0.179, 95% CI [-0.431, 0.126]); the perfect binary separation is not evidence of a graded causal-use meter.
# isolation {
#   "status": "PASS",
#   "baseline_head": "eb9e44144de7d05d4a8e93f975d1af1351b0d87d",
#   "baseline_is_ancestor": true,
#   "changed_paths": [
#     "notebooks/v6_1_within_engine.ipynb",
#     "notebooks/v6_2_hard_dashboard.ipynb",
#     "notebooks/v6_3_distributions.ipynb",
#     "notebooks/v6_4_report.ipynb",
#     "results/v6/RESULTS_v6.md",
#     "results/v6/figures/F_v6_1_engine_only_read_vs_c.png",
#     "results/v6/figures/F_v6_2_old_vs_hard_dashboard_auc.png",
#     "results/v6/figures/F_v6_3_read_ig_distributions.png",
#     "results/v6/metrics_v6.json",
#     "results/v6/raw/v6_1_within_engine.json",
#     "results/v6/raw/v6_2_hard_dashboard_analysis.json",
#     "results/v6/raw/v6_2_hard_dashboard_causal.json",
# ...
