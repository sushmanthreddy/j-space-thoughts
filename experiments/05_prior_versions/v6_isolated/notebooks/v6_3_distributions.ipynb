# %% [markdown]
# # v6.3 — Raw READ_IG distributions
#
# Compare frozen engines, old arithmetic dashboards, and verified answer-type-matched hard dashboards. Quantify observed range overlap and diagnose whether arithmetic answer type explains the original separation.

# %%
import os
import sys
from pathlib import Path

root = Path('/home/jovyan/j-space-thoughts')
os.chdir(root)
sys.path.insert(0, str(root))
script = root / 'scripts/run_distributions_v6.py'
exec(compile(script.read_text(), str(script), 'exec'), {'__name__': '__main__'})
# Out:
# distribution summaries {
#   "engine": {
#     "name": "engine",
#     "n": 77,
#     "minimum": 0.034969571977853775,
#     "q1": 0.14966484904289246,
#     "median": 0.21024686098098755,
#     "q3": 0.2629484534263611,
#     "maximum": 0.9927703738212585,
#     "mean": 0.2585712923825561,
#     "population_std": 0.1983298012461715,
#     "median_absolute_deviation": 0.06058201193809509,
#     "iqr": 0.11328360438346863,
#     "range_width": 0.9578008018434048,
#     "n_unique": 77,
#     "all_identical": false,
#     "near_zero_atol": 0.001,
#     "n_near_zero": 0,
#     "fraction_near_zero": 0.0
#   },
#   "hard_dashboard": {
#     "name": "hard_dashboard",
#     "n": 77,
#     "minimum": 0.0016503171063959599,
#     "q1": 0.004161945078521967,
#     "median": 0.00631862273439765,
#     "q3": 0.010945355519652367,
#     "maximum": 0.021032409742474556,
#     "mean": 0.008233332371508533,
#     "population_std": 0.004981742616149297,
# ...
